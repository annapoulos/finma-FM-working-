# %% [markdown]
# # Opening and Reading .ipynb Notebook Files
#
# This notebook demonstrates how to open and read a .ipynb notebook file programmatically using Python.

# %% [markdown]
# ## Section 1: Import Required Libraries
#
# Import necessary libraries such as json, pathlib, and nbformat for working with notebook files.

# %%
import json
from pathlib import Path
import nbformat
from typing import List, Dict, Any

# %% [markdown]
# ## Section 2: Specify the Notebook File Path
#
# Define the path to the .ipynb notebook file you want to open and load.

# %%
# Specify the path to the notebook file
notebook_path = Path('notebook_reader.ipynb')

# Verify the file exists
if notebook_path.exists():
    print(f"Notebook found at: {notebook_path.absolute()}")
else:
    print(f"Notebook not found at: {notebook_path}")
    # Create a sample path for demonstration
    notebook_path = Path('/workspaces/finma-FM-working-/notebook_reader.ipynb')
# Out:
# Notebook found at: /workspaces/finma-FM-working-/notebook_reader.ipynb

# %% [markdown]
# # This is a heading
# ## This is a less major heading
# Here is some **bold** text
